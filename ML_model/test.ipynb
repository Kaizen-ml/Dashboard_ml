# %%
import pandas as pd

df = pd.read_csv("processed/liquid_cooling_data.csv")

print(df["avg_T_out"].describe())
# Out:
# count    26981.000000
# mean        -0.002445
# std          0.994155
# min         -1.575253
# 25%         -0.893429
# 50%         -0.082814
# 75%          0.678557
# max          3.519489
# Name: avg_T_out, dtype: float64
